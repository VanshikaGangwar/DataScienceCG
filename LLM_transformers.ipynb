# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will be one of the major issues facing humanity as it begins its journey toward a globalised world.\n\nAI will be used in the production of food, medicine, construction, technology and even in the production of goods and services. We will also be using AI to design, build, manage and use the robots in order to create new forms of consciousness.\n\nAI will also be used in the production of medicine, the building of healthcare systems, the construction of housing systems and the design of space transportation. All these will be automated in an effort to create more sustainable economies, while at the same time improving quality, efficiency, and sustainability.\n\nIn addition, we will also be using AI to design and build products that are designed to be of benefit to the people of the planet.\n\nIn addition to these applications, there will be a wider range of applications.\n\nA new dimension of research\n\nAs we move towards the next phase of AI in the field of AI, we will have to look at a lot of different areas.\n\nSome of these areas include:\n\nArtificial Intelligence\n\nArtificial Intelligence, or AI for short, is the ability to create new and exciting things on top of existing knowledge. The main part of this'}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”

from transformers import pipeline

# Load GPT-2 text generation pipeline
generator = pipeline("text-generation", model="gpt2")

prompt = "The hero enters the ancient forest and discovers"

result = generator(
    prompt,
    max_length=80,      # maximum length of generated text
    num_return_sequences=1,  # number of generated outputs
    temperature=0.8     # randomness (0.7–1.0 is good for creativity)
)

# Print generated story
print(result[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The hero enters the ancient forest and discovers that the gods have already taken the land and are setting it in its place. He is soon confronted by an ancient man who tells him that they have stolen the land and are about to have a battle. The hero attempts to defend himself but the ancient man is enraged and starts throwing knives at him. The sword is thrown at the hero and the man falls from the sky.
#
# The hero is given a very rare "I'm a hero, give me a medal!" medal. The guy is on first aid at a hospital.
#
# The hero is attacked and killed by three mysterious men as is happening at the center of the forest. The hero flees and is subsequently taken by the two men who took the hero, but the hero refuses to flee and is killed.
#
# The hero is given a very rare "I'm a hero, give me a medal!" medal. The guy is on first aid at a hospital. The hero flees and is subsequently taken by the two men who took the hero, but the hero refuses to flee and is killed. The hero is given another "I'm a hero, give me a medal!" medal from the ancient man who is then killed by a mysterious man.

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import BertTokenizer

# Load pretrained BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Patient query
text = "I have chest pain and shortness of breath"

# Tokenize the sentence
tokens = tokenizer.tokenize(text)

print("Tokens:", tokens)
# Out:
# Tokens: ['i', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is in the hands of the people.\n\nThe future of Artificial Intelligence is'}]
# [{'generated_text': 'The future of Artificial Intelligence and our future of robotics, says Paul Molloy, a senior researcher at The New York Times. The idea that robots could replace human drivers as much as 3-D printers could be an exciting one for a variety of reasons. One is that robots could be used to automate tasks that humans would never be able to do. Robots are also being able to perform mundane tasks that humans never could. In the next couple of decades, that could change.\n\nOther potential applications include a combination of machine learning technologies and human-machine interactions, says Molloy. And, he says, the future of automation is just starting.\n\nBut you can\'t just run a game and have someone beat you up.\n\n"You have to train people to be human-driven, and to do that, you have to be able to do it yourself and put that into practice," explains Molloy. "You have to have a good training problem and a good learning problem to solve it."\n\nAnd, you\'ll still need to have those skills, but they\'ll be there.\n\n"One of the things people don\'t realize that they are dealing with really is a lot of people in this field are very, very interested in the idea of doing computer'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

from transformers import pipeline

# Load GPT-2 text generation model
generator = pipeline("text-generation", model="gpt2")

# Writer's prompt
prompt = "The future of Artificial Intelligence"

# Low temperature (more predictable)
low_temp_output = generator(
    prompt,
    max_length=50,
    temperature=0.2,
    num_return_sequences=1
)

# High temperature (more creative)
high_temp_output = generator(
    prompt,
    max_length=50,
    temperature=0.8,
    num_return_sequences=1
)

print("Temperature = 0.2 (Formal Output)")
print(low_temp_output[0]["generated_text"])

print("\nTemperature = 0.8 (Creative Output)")
print(high_temp_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature = 0.2 (Formal Output)
# The future of Artificial Intelligence is not yet clear. But the question is whether we will ever be able to solve it.
#
# In the meantime, we can look forward to the next generation of artificial intelligence.
#
# Temperature = 0.8 (Creative Output)
# The future of Artificial Intelligence, and how much of this will be a matter of interest to us, will depend on the future of robotics, and on what kind of "smart" robots are the best choice for our jobs and lives.
#
# As it turns out, robots are not just for personal assistants but for the job of monitoring, designing, and training our entire lives. We have been using them for some time now, but we now have to understand what they are and what they do for us.
#
# In 2012, a team of computer scientists at the University of Texas at Austin, led by Dr. Tim Kurzweil, performed research called "Machine Learning: In the Real World," that investigated the role of autonomous robots in making decisions. Kurzweil's team used information provided by the state of Georgia, a major U.S. economy with a population of more than 2 million people, and by the Internet.
#
# The team also developed a method for building self-driving cars that used natural-gas-dense, low-temperature water vapor. This method was able to build self-driving cars using the data collected over a 20-year period. The results indicate that a robot with an artificial brain can quickly detect and eliminate the dangers of driving with

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: Impact of social media on college students
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Impact of social media on college students
#
# College students often suffer from post-secondary trauma. According to a Pew Research Center study released in March, between 2007 and 2012, more than one in four college students went to college with a mental illness.
#
# In fact, nearly two-thirds of college students admit to having had at least one social media post.
#
# This is particularly true of students at minority-students colleges. Nearly half of the college students admitted to having at least one social media post in 2012, compared with 17 percent of the general population.
#
# The Pew Research Center study indicates that one in three (18 percent) college students who do not have an active social media account reported that they suffered from post-secondary trauma.
#
# On the flip side, only one in three college students who have a social media account reported experiencing trauma, compared with 3 percent of the general population.
#
# A 2013 study by the National Center for Education Statistics found that nearly three out of four college students have at least one social media account and that nearly one-quarter of the college students who have a social media account reported having a mental health issue.
#
# According to the study, "Social media exposure and mental health are related. Psychological conditions such as depression and anxiety might be at the

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

from transformers import pipeline

# Load GPT-2 text generation pipeline
generator = pipeline("text-generation", model="gpt2")

# Ask student for prompt
prompt = input("Enter a prompt: ")

# Generate essay continuation
result = generator(
    prompt,
    max_length=50,          # generate up to 50 tokens
    num_return_sequences=1, # one output
    temperature=0.7         # balanced creativity
)

# Display generated text
print("\nGenerated Essay Idea:\n")
print(result[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Essay Idea:
#
# The impact of technology on education is not clear, but is likely to be large, and likely to be difficult to measure. The effects of new technologies on students are well understood and have been discussed by the world, and there are several theoretical frameworks for studying the effects of technology on learning. A recent paper in the journal PLOS ONE proposes that students learn more effectively through their reading, reading comprehension, and problem solving skills for use in classrooms.
#
# The focus of this work has been on learning for children with disabilities and their caregivers. It does not address or address how technology affects the learning of their children. The data used in this study are from the National Center for Education Statistics (NCES), the National Center for Education Statistics (NCE), the National Science Foundation, the National Center for Health Statistics (NCHS), the National Center for Environmental Health Sciences (NEPHS), the National Center for Health Statistics (NCHS), and the National Center for Health Statistics (NCDSS). The data are grouped into six categories: primary, secondary, tertiary, and intergenerational. A total of 3,000 child-care providers (child-care institutions that provide child care services for children of all ages, including preschoolers and seniors) provide services to children of all ages.

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the way we think about our interactions with machines. If we don\'t understand a machine\'s mind, why should we interact with it? It\'s not as if we don\'t understand what it\'s doing. It\'s as if we don\'t understand what it\'s thinking and trying to control it. It\'s as if we\'re completely unaware of what it\'s about. It\'s almost like a subconscious understanding.\n\nThe problem is that the machines that humans interact with are so complex that they have little information about the world around them. If we take the idea of a machine, we have a very limited understanding of how it works. If we can understand how it goes about being used, we have a limited understanding of how it works.\n\nThe problem is that the machines that humans interact with are so complex that they have little information about the world around them. If we take the idea of a machine, we have a very limited understanding of how it goes about being used, and we don\'t even know what it\'s doing.\n\nI have to say that I\'m sick of talking about a lack of understanding. I think it\'s kind of like the question, "What is it that makes humans so useful?"\n\nWell, the answer is that we don'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the way people see themselves — and even the way they see themselves — from a corporate perspective, to a human-centered perspective.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.

from transformers import pipeline

# Prompt given by teacher
prompt = "Artificial Intelligence will transform"

# GPT-2 model
gpt2_generator = pipeline("text-generation", model="gpt2")

gpt2_output = gpt2_generator(
    prompt,
    max_length=40,
    num_return_sequences=1
)

# DistilGPT-2 model
distilgpt2_generator = pipeline("text-generation", model="distilgpt2")

distil_output = distilgpt2_generator(
    prompt,
    max_length=40,
    num_return_sequences=1
)

# Print results
print("GPT-2 Output:\n")
print(gpt2_output[0]["generated_text"])

print("\nDistilGPT-2 Output:\n")
print(distil_output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
#
# Artificial Intelligence will transform the way we think about AI. The big leap forward in this area is coming from AI as a product or technology, rather than as a commodity or a commodity group. This is the future of AI.
#
# It's not just that the future of AI will be better than ours. It's also that AI will be more powerful than our current "smart" systems.
#
# Yes, AI is going to be far better than our current version of technology. But AI is not going to replace our current social, political and economic system. It's going to replace us.
#
# The next step for AI is to replace our current social, political and economic system with a system that enables us to do all those things. We are going to go beyond our current system of social, political and economic equality, and replace that with a new and more democratic system of equality.
#
# "The next step for AI is to replace our current social, political and economic system with a system that enables us to do all those things." - Bill Gates
#
# Bill Gates's vision for AI is a multi-dimensional problem where there is no simple order, and no time to fix it. Our current social system, in this case, has a very complex set of problems, and
#
# DistilGPT-2 Output:
#
# Artificial Intelligence will transform people’s minds’ and their minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s minds’ and they will change their minds’s and they will change their minds’s and they will change their minds’s and they will change their minds’s and they will change their minds’s and they will change their minds’s and they will change their minds’s and they will change their minds’s and they will change
